# %% [markdown]
# <a href="https://colab.research.google.com/github/finardi/tutos/blob/master/anchorRanking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Aug  3 02:30:22 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    41W / 300W |   1681MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %%capture
# !pip install magic_timer

# basics imports
import gc
import os
import pickle
import random
import numpy as np
import pandas as pd
from magic_timer import MagicTimer
 
# sklearn imports
from sklearn.metrics import classification_report, f1_score
 
# torch imports
import torch 
from torch.utils.data import DataLoader

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
manual_seed = 341
 
def deterministic(rep=True):
    if rep:
        np.random.seed(manual_seed)
        torch.manual_seed(manual_seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed(manual_seed)
            torch.cuda.manual_seed_all(manual_seed)
        torch.backends.cudnn.enabled = False 
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
        print(f'Deterministic experiment, seed: {manual_seed}')
    else:
        print('Random experiment')
 
deterministic()
# Out:
# Deterministic experiment, seed: 341

# %% [markdown]
# # Load DataPrep and objects

# %%
def pickle_file(path, data=None):
    if data is None:
        with open(path, 'rb') as f:
            return pickle.load(f)
    if data is not None:
        with open(path, 'wb') as handle:
            pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)
 
path_load = '/content/drive/MyDrive/Colab/AVI-PROATIVO/avi_proativo_modelo/EXPERIMENTOS/'
 
# Loading
similar_ids = pickle_file(path_load+'similar_ids')
X_train = pickle_file(path_load+'X_train_transform')
y_train = pickle_file(path_load+'y_train')
X_test  = pickle_file(path_load+'X_test_transform')
y_test  = pickle_file(path_load+'y_test')

# X_train = pickle_file(path_load+'X_train_transform_no_scale')
# y_train = pickle_file(path_load+'y_train_no_scale')
# X_test  = pickle_file(path_load+'X_test_transform_no_scale')
# y_test  = pickle_file(path_load+'y_test_no_scale')
data_feats = pickle_file(path_load+'data_feats')

assert len(X_train) == len(y_train)
assert len(X_test) == len(y_test)

int_to_class = {k:v for v,k in data_feats['assuntos'].items()}
print(int_to_class)

X_train
# Out:
# {0: 'cancelamento do cartão de crédito', 1: 'avaliação emergencial de crédito', 2: 'contestar transações', 3: 'desbloquear o cartão', 4: 'rotativo - pagamento mínimo', 5: 'alterar limite do cartão de crédito', 6: 'renegociação - palavra curta'}
#         aut_val_orgl_tran_tr  ...  avi_ultima_intencao_retornada
# 0                   2.408347  ...                              3
# 1                  -0.803916  ...                              3
# 2                  -0.840751  ...                              3
# 3                   1.540535  ...                              0
# 4                  -0.374214  ...                              0
# ...                      ...  ...                            ...
# 223730              1.704635  ...                              2
# 223731             -0.669826  ...                              2
# 223732             -0.203593  ...                              0
# 223733             -0.088817  ...                              2
# 223734             -0.777258  ...                              2
#
# [223735 rows x 31 columns]

# %% [markdown]
# ## Remove duplicates and Sampling a chunk

# %%
X_train['TARGET'] = y_train
X_test['TARGET'] = y_test

print(f'X_train.shape com noise: {X_train.shape}')

# add id column to remove similiar/noise samples
X_train['ID'] = np.arange(len(X_train))

# filter
X_train = X_train[~X_train.ID.isin(similar_ids)]

# drop ID column
X_train.drop(columns='ID', inplace=True)
 
print(f'X_train.shape com duplicates: {X_train.shape}')
print(f'X_test.shape  com duplicates: {X_test.shape}')
 
X_train.drop_duplicates(inplace=True)
X_test.drop_duplicates(inplace=True)
 
print(f'X_train.shape sem duplicates: {X_train.shape}')
print(f'X_test.shape  sem duplicates: {X_test.shape}')
 
# Sampling dataframe
SAMPLING = False
if SAMPLING:
    data_list = []
    for target_class in range(X_train.TARGET.nunique()):
        data = X_train[X_train.TARGET == target_class].sample(frac=0.001)
        data_list.append(data)
    
    X_train = pd.concat(data_list).sample(frac=1).reset_index(drop=True)
    print(f'\nX_train.shape with sampling: {X_train.shape}')
    X_train
# Out:
# X_train.shape com noise: (223735, 32)
# X_train.shape com duplicates: (222723, 32)
# X_test.shape  com duplicates: (20050, 32)
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# X_train.shape sem duplicates: (214424, 32)
# X_test.shape  sem duplicates: (19691, 32)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Build triplet dataset

# %%
# TRAIN dict: key[int]-> value: feats-one row df 
featid_TRAIN = {k:v[1] for k,v in enumerate(X_train.iloc[:, :-1].iterrows())}
assert len(featid_TRAIN) == X_train.shape[0]
targetid_TRAIN = {k:v[1].values for k,v in enumerate(X_train.iloc[:, -1:].iterrows())}
assert len(targetid_TRAIN) == X_train.shape[0]
 
# TEST dict: key[int]-> value: feats-one row df 
featid_TEST = {k:v[1] for k,v in enumerate(X_test.iloc[:, :-1].iterrows())}
assert len(featid_TEST) == X_test.shape[0]
targetid_TEST = {k:v[1].values for k,v in enumerate(X_test.iloc[:, -1:].iterrows())}
assert len(targetid_TEST) == X_test.shape[0]

# make df triplets
def make_avip_triplets(featid:dict, targetid:dict, all_labels:list, n_negatives=3):
    if n_negatives >= len(all_labels):
        n_negatives = len(all_labels)-1 # -1 is the true label

    feat_list, pos_target, neg_target = [], [], []
    for idx in featid.keys():
        pos_label = int(targetid[idx])
        
        neg_label = np.random.choice(
            list((set(all_labels) - set([pos_label]))), size=(n_negatives,), replace=False)
        for n in range(n_negatives):
            pos_target.append(pos_label)
            neg_target.append(neg_label[n])
            feat_list.append(idx)
 
    assert len(pos_target) == len(neg_target) == len(feat_list)
    
    data_TRIPLET = pd.DataFrame(
        {
            'feat_id': feat_list, 
            'pos_target': pos_target, 
            'neg_target': neg_target,
        })
    
    return data_TRIPLET
 
# ✨ - - - - - running triplets
all_labels = list(X_train.TARGET.unique())
df_train_TRIPLET = make_avip_triplets(
    featid=featid_TRAIN, 
    targetid=targetid_TRAIN, 
    all_labels=all_labels, 
    n_negatives=6,
    )
df_test_TRIPLET = make_avip_triplets(
    featid=featid_TEST, 
    targetid=targetid_TEST, 
    all_labels=all_labels, 
    n_negatives=1,
    ) 

df_train_TRIPLET
# Out:
#          feat_id  pos_target  neg_target
# 0              0           5           1
# 1              0           5           0
# 2              0           5           2
# 3              0           5           4
# 4              0           5           6
# ...          ...         ...         ...
# 1286539   214423           1           4
# 1286540   214423           1           3
# 1286541   214423           1           5
# 1286542   214423           1           2
# 1286543   214423           1           6
#
# [1286544 rows x 3 columns]

# %% [markdown]
# # Build Dataset and Dataloader

# %%
BSIZE = 1024

class AVIGenerator():
    def __init__(self, data_triplet, featid_data, num_cols, cat_cols):
        super().__init__()
 
        self.featid_data = featid_data
        self.feat_id = data_triplet.feat_id.values
        self.pos_target = data_triplet.pos_target.values
        self.neg_target = data_triplet.neg_target.values
        
        self.num_cols = num_cols
        self.cat_cols = cat_cols
            
    def __len__(self):
        return self.feat_id.shape[0]
    
    def __getitem__(self, idx):
        cat_feats = torch.LongTensor(self.featid_data[self.feat_id[idx]][self.cat_cols].values)
        num_feats = torch.FloatTensor(self.featid_data[self.feat_id[idx]][self.num_cols].values)
        pos_target = torch.tensor(self.pos_target[idx])
        neg_target = torch.tensor(self.neg_target[idx])
            
        return cat_feats, num_feats, pos_target, neg_target
 
ds_train = AVIGenerator(df_train_TRIPLET, featid_TRAIN, data_feats['num_feats'], data_feats['cat_feats'])
ds_test  = AVIGenerator(df_test_TRIPLET,  featid_TEST,  data_feats['num_feats'], data_feats['cat_feats'])

dataloaders = {
    'train': DataLoader(
        ds_train, 
        batch_size=BSIZE,
        shuffle=True, 
        num_workers=os.cpu_count()),
    'test': DataLoader(
        ds_test, 
        batch_size=BSIZE,
        shuffle=False,
        num_workers=os.cpu_count())
    }

# ✨ - - - - - running dataset and Dataloader
ds = AVIGenerator(
        df_train_TRIPLET,
        featid_TRAIN, 
        data_feats['num_feats'], 
        data_feats['cat_feats'], 
)
cat_feats, num_feats, pos_target, neg_target = ds[0]
cat_feats_b, num_feats_b, pos_target_b, neg_target_b = next(iter(dataloaders['train']))
cat_feats_b.shape, num_feats_b.shape, pos_target_b.shape, neg_target_b.shape
# Out:
# (torch.Size([1024, 3]),
#  torch.Size([1024, 28]),
#  torch.Size([1024]),
#  torch.Size([1024]))

# %% [markdown]
# # Model

# %%
class NNRanking(torch.nn.Module):
    def __init__(self, embedding_sizes=data_feats['emb_szs'], n_cont=len(data_feats['num_feats']), 
                 n_classes=len(all_labels), dmodel=128, p=2):
        super().__init__()
        
        self.p = p

        self.embds = torch.nn.ModuleList(
            [torch.nn.Embedding(categories, size) for categories, size in embedding_sizes])
        
        n_emb_sum = sum(e.embedding_dim for e in self.embds) 
        self.actv = torch.nn.ReLU()
        self.drop = torch.nn.Dropout()
        self.linear_1 = torch.nn.Linear(n_emb_sum + n_cont, 8 * dmodel)
        self.linear_2 = torch.nn.Linear(8 * dmodel, 8 * dmodel)
        self.linear_3 = torch.nn.Linear(8 * dmodel, dmodel//2)
        
        self.embds_class = torch.nn.Embedding(n_classes, dmodel//2)

    def forward(self, cat_feats, num_feats, pos_targets, neg_targets):
        
        # processing anchor -> feats
        feats = self.process_feats(cat_feats, num_feats)

        # processing neg targets 
        neg_targets = self.process_target(neg_targets)

        # processing pos targets
        pos_targets = self.process_target(pos_targets)

        return feats, pos_targets, neg_targets
    
    def process_feats(self, cat_feats, num_feats):
        cats = [e(cat_feats[:,i]) for i, e in enumerate(self.embds)]
        cats = torch.cat(cats, dim=1).to(device)
        feats = torch.cat((num_feats, cats), dim=1)
        feats = self.linear_1(feats)
        feats = self.drop(self.actv(feats))
        feats = self.linear_2(feats)
        feats = self.drop(self.actv(feats))
        feats = self.linear_3(feats)
        return torch.nn.functional.normalize(feats, p=self.p, dim=-1)

    def process_target(self, target):
        embd_target = self.embds_class(target)
        return torch.nn.functional.normalize(embd_target, p=self.p, dim=-1)             

def init_weights(m):
    if type(m) == torch.nn.Linear or type(m) == torch.nn.Embedding:
        torch.nn.init.xavier_uniform_(m.weight)

# ✨ - - - - - running NNRanking
Net = NNRanking(dmodel=256, p=1).to(device)
 

 # init weights
Net.apply(init_weights)

anchor, pos, neg = Net(cat_feats_b.to(device), 
    num_feats_b.to(device), 
    pos_target_b.to(device),
    neg_target_b.to(device), 
    ) 
anchor.shape, pos.shape, neg.shape
# Out:
# (torch.Size([1024, 128]), torch.Size([1024, 128]), torch.Size([1024, 128]))

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
 
_ = 48
print('\n','=' * _,f'\n # The model has {count_parameters(Net):,}' \
       ' trainable parameters #\n', '=' * _,'\n' )
Net
# Out:
#  ================================================
#  # The model has 5,171,142 trainable parameters #
#  ================================================
# NNRanking(
#   (embds): ModuleList(
#     (0): Embedding(45, 30)
#     (1): Embedding(251, 128)
#     (2): Embedding(258, 128)
#   )
#   (actv): ReLU()
#   (drop): Dropout(p=0.5, inplace=False)
#   (linear_1): Linear(in_features=314, out_features=2048, bias=True)
#   (linear_2): Linear(in_features=2048, out_features=2048, bias=True)
#   (linear_3): Linear(in_features=2048, out_features=128, bias=True)
#   (embds_class): Embedding(7, 128)
# )

# %%
# anchor->feats, pos->embd_classe_pos, neg->embd_classe_neg 
def triple_loss(anchor, pos, neg, margin=0.3, p=2): 
    d = torch.nn.PairwiseDistance(p=2)
    distance = margin - (d(anchor, pos) - d(anchor, neg)) 
    loss = torch.mean(torch.max(distance, torch.zeros_like(distance))) 
    return loss    

def train(model, dataloader, device, loss_fct=triple_loss, margin=0.3, p=2):
    model.train()
    train_loss = 0
    for batch in dataloader:
        optimizer.zero_grad()
        cat_feats, num_feats, pos_target, neg_target = batch

        anchor, pos, neg = model(
            cat_feats.to(device), 
            num_feats.to(device), 
            pos_target.to(device), 
            neg_target.to(device), 
            )
        
        loss = loss_fct(anchor, pos, neg, margin, p)
        train_loss += loss.item()
        
        loss.backward()
        optimizer.step()

    total_loss = train_loss/len(dataloader)
    return total_loss

class Metrics:
    def __init__(self, mrr_depths:set, recall_depths:set, success_depths:set):
        self.results = {}
        self.mrr_sums = {depth:0.0 for depth in mrr_depths}
        self.recall_sums = {depth:0.0 for depth in recall_depths}
        self.success_sums = {depth:0.0 for depth in success_depths}

    def get_result(self, query_idx, query_key, ranking, gold_positives):
        assert query_key not in self.results
        assert len(self.results) <= query_idx
        assert len(set(gold_positives)) == len(gold_positives)
        assert len(set([pid for pid in ranking])) == len(ranking)

        self.results[query_key] = ranking

        positives = [i for i, hit in enumerate(ranking) if hit in gold_positives]

        if len(positives) == 0:
            return

        for depth in self.mrr_sums:
            first_positive = positives[0]
            self.mrr_sums[depth] += (1.0 / (first_positive+1.0)) if first_positive < depth else 0.0

        for depth in self.success_sums:
            first_positive = positives[0]
            self.success_sums[depth] += 1.0 if first_positive < depth else 0.0

        for depth in self.recall_sums:
            num_positives_up_to_depth = len([pos for pos in positives if pos < depth])
            self.recall_sums[depth] += num_positives_up_to_depth / len(gold_positives)

    def print_metrics(self, query_idx):
        print('- '*10)
        for depth in sorted(self.mrr_sums):
            mrr_value =  self.mrr_sums[depth] / (query_idx+1.0)
            print(f"MRR@{str(depth):<2} = {mrr_value:.3}")
        
        print('- '*10)
        for depth in sorted(self.recall_sums):
            recall_value = self.recall_sums[depth] / (query_idx+1.0)
            print(f"Recall@{str(depth):<2} = {recall_value:.3}")
        print('- '*10)
        for depth in sorted(self.success_sums):
            success_value = self.success_sums[depth] / (query_idx+1.0)
            print(f"Success@{str(depth):<2} = {success_value:.3}")
        print('- '*10)

def predict_one_sample(model, cat_feats, num_feats, target, num_classes, device='cpu', assuntos=None):
    model.eval()
    with torch.no_grad():
        classes = model.process_target(torch.tensor(list(assuntos.keys())).to(device))
        
        feat = model.process_feats(
            cat_feats.unsqueeze(0).to(device), 
            num_feats.unsqueeze(0).to(device),
            )

        d = torch.nn.PairwiseDistance(p=2)
        score = d(feat, classes)

    pred = score.argmax(-1).cpu().numpy().tolist()
    true = target.cpu().numpy().tolist()

    score = score.detach().cpu()
    score = score.sort(descending=True)

    ranked = score.indices.tolist()

    if assuntos is not None:
        ranked_str = [assuntos[e] for e in ranked]
        true_str = assuntos[true]
    ranked_score = score.values.tolist()

    return ranked, ranked_str, true, true_str, ranked_score

def eval_ranking(model, dataset, featid, device=device, assuntos=int_to_class, metrics=None, verbose=False, run_all=None):
    keys = sorted(list(featid.keys()))
    random.shuffle(keys)

    preds, trues = [], []
    for query_idx, qid in enumerate(keys):
        query = featid[qid]
        cat_feats, num_feats, target,_ = dataset[query_idx]
        
        ranked, ranked_str, true, true_str, ranked_score = predict_one_sample(
            model=model, 
            cat_feats=cat_feats, 
            num_feats=num_feats, 
            target=target, 
            num_classes=len(assuntos), 
            device=device, 
            assuntos=assuntos,
            )
        preds.append(data_feats['assuntos'][ranked_str[0]])
        trues.append(data_feats['assuntos'][true_str])
        
        if metrics is not None:
            metrics.get_result(
                query_idx=query_idx, 
                query_key=qid, 
                ranking=ranked, 
                gold_positives=[true],
                )
        
        if metrics is not None and verbose:
            if query_idx % 1_000==0 and query_idx !=0:
                print(f'\nRanking metrics at {query_idx} examples')
                metrics.print_metrics(query_idx)
        if query_idx == run_all: 
            break
    f1 = f1_score(trues, preds, average="macro")
    print(f'F1: {f1:<5.3}', end=' -- time:')
    
    return trues, preds, f1

_, _, f1 = eval_ranking(model=Net, dataset=ds_test, featid=featid_TEST)
# Out:
# F1: 0.0723 -- time:

# %% [markdown]
# #✨ Run training

# %%
try:
    del Net
    gc.collect()
    torch.cuda.empty_cache()
except:
    pass
deterministic()

#norm type
p_norm = 2

# Network
Net = NNRanking(dmodel=256, p=p_norm).to(device)

# init Network weights 
Net.apply(init_weights)

# embd class freezed?
FREEZE = True
if FREEZE:
    Net.embds_class.weight.requires_grad = False
 
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, Net.parameters()))

N_EPOCHS = 30
best_f1 = 0
timer = MagicTimer()
print(f'\n>>> Training for {N_EPOCHS} epochs <<<\n')

# ---------------------------------------------------------------------------------------
for i in range(1, N_EPOCHS+1):
    train_loss = train(
        model=Net, 
        dataloader=dataloaders['train'], 
        device=device, 
        margin=0.3,
        p=p_norm,
        )
    
    print(f'Epoch [{i:>2}/{N_EPOCHS} ] -- train loss: {(train_loss):.4f}', end=' ✨ ')
    _, _, f1 = eval_ranking(
        model=Net, 
        dataset=ds_test, 
        featid=featid_TEST, 
        )    
    print(f' {timer}')

    if f1 > best_f1:
        best_f1 = f1
        torch.save(Net.state_dict(), 'Epoch.pth')
        print(f'Saving epoch {i}')
# Out:
# Deterministic experiment, seed: 341
#
# >>> Training for 30 epochs <<<
#
# Epoch [ 1/30 ] -- train loss: 0.1516 ✨ F1: 0.394 -- time: 8.8 minutes
# Saving epoch 1
# Epoch [ 2/30 ] -- train loss: 0.1435 ✨ F1: 0.389 -- time: 18 minutes
# Epoch [ 3/30 ] -- train loss: 0.1392 ✨ F1: 0.404 -- time: 27 minutes
# Saving epoch 3
# Epoch [ 4/30 ] -- train loss: 0.1352 ✨ F1: 0.404 -- time: 35 minutes
# Saving epoch 4
# Epoch [ 5/30 ] -- train loss: 0.1313 ✨ F1: 0.4   -- time: 44 minutes
# Epoch [ 6/30 ] -- train loss: 0.1278 ✨ F1: 0.401 -- time: 53 minutes
# Epoch [ 7/30 ] -- train loss: 0.1243 ✨ F1: 0.399 -- time: 1.1 hours
# Epoch [ 8/30 ] -- train loss: 0.1212 ✨ F1: 0.398 -- time: 1.2 hours
# Epoch [ 9/30 ] -- train loss: 0.1184 ✨ F1: 0.394 -- time: 1.4 hours
# Epoch [10/30 ] -- train loss: 0.1159 ✨ F1: 0.396 -- time: 1.5 hours
# Epoch [11/30 ] -- train loss: 0.1135 ✨ F1: 0.396 -- time: 1.6 hours
# Epoch [12/30 ] -- train loss: 0.1113 ✨ F1: 0.395 -- time: 1.8 hours
# Epoch [13/30 ] -- train loss: 0.1093 ✨ F1: 0.396 -- time: 1.9 hours
# Epoch [14/30 ] -- train loss: 0.1073 ✨ F1: 0.394 -- time: 2.1 hours
# Epoch [15/30 ] -- train loss: 0.1056 ✨ F1: 0.395 -- time: 2.2 hours
# Epoch [16/30 ] -- train loss: 0.1039 ✨ F1: 0.388 -- time: 2.3 hours
# Epoch [17/30 ] -- train loss: 0.1024 ✨ F1: 0.389 -- time: 2.5 hours
# Epoch [18/30 ] -- train loss: 0.1011 ✨ F1: 0.39  -- time: 2.6 hours
# Epoch [19/30 ] -- train loss: 0.0996 ✨ F1: 0.389 -- time: 2.8 hours
# Epoch [20/30 ] -- train loss: 0.0984 ✨ F1: 0.39  -- time: 2.9 hours
# Epoch [21/30 ] -- train loss: 0.0973 ✨ F1: 0.388 -- time: 3.1 hours
# Epoch [22/30 ] -- train loss: 0.0959 ✨ F1: 0.39  -- time: 3.2 hours
# Epoch [23/30 ] -- train loss: 0.0948 ✨ F1: 0.389 -- time: 3.4 hours
# Epoch [24/30 ] -- train loss: 0.0936 ✨ F1: 0.387 -- time: 3.5 hours
# Epoch [25/30 ] -- train loss: 0.0928 ✨ F1: 0.387 -- time: 3.7 hours
# Epoch [26/30 ] -- train loss: 0.0917 ✨ F1: 0.387 -- time: 3.8 hours
# Epoch [27/30 ] -- train loss: 0.0909 ✨ F1: 0.386 -- time: 3.9 hours
# Epoch [28/30 ] -- train loss: 0.0900 ✨ F1: 0.389 -- time: 4.1 hours
# Epoch [29/30 ] -- train loss: 0.0891 ✨ F1: 0.387 -- time: 4.2 hours
# Epoch [30/30 ] -- train loss: 0.0884 ✨ F1: 0.384 -- time: 4.4 hours

# %% [markdown]
# #✨ Run best F$_1$ epoch

# %%
Net.load_state_dict(torch.load('/content/Epoch.pth'))

def show_rank_vector(model, dataset, assuntos=int_to_class, data_feats=data_feats, k=50):
    preds, trues = [], []
    for idx in range(len(ds_test)):
        cat_feats, num_feats, pos_target, _ = dataset[idx]
        ranked, ranked_str, true, true_str, ranked_score = predict_one_sample(
                model=model, 
                cat_feats=cat_feats, 
                num_feats=num_feats, 
                target=pos_target, 
                num_classes=len(assuntos), 
                device=device, 
                assuntos=assuntos,
                )
        preds.append(data_feats['assuntos'][ranked_str[0]])
        trues.append(data_feats['assuntos'][true_str])

        print('Ranking Preds', ranked_str)
        print('Scores', ranked_score)
        print('True Label:', true_str)
        print()
        if idx == k: break

# ✨ - - - - - running ranked vector
show_rank_vector(model=Net, dataset=ds_test, assuntos=int_to_class, data_feats=data_feats, k=50)
print('\n\n')

# ✨ - - - - - running eval in best epoch with ranking metrics
metrics = Metrics(mrr_depths={1, 2, 3}, recall_depths= {1, 2, 3}, success_depths={1, 2, 3})
trues, preds, _ = eval_ranking(model=Net, dataset=ds_test, featid=featid_TEST, metrics=metrics, verbose=True)
# Out:
# Ranking Preds ['avaliação emergencial de crédito', 'desbloquear o cartão', 'contestar transações', 'rotativo - pagamento mínimo', 'renegociação - palavra curta', 'cancelamento do cartão de crédito', 'alterar limite do cartão de crédito']
# Scores [1.7062146663665771, 1.6441941261291504, 1.599846601486206, 1.244102120399475, 1.2013646364212036, 1.1558399200439453, 1.1428910493850708]
# True Label: rotativo - pagamento mínimo
#
# Ranking Preds ['avaliação emergencial de crédito', 'desbloquear o cartão', 'contestar transações', 'alterar limite do cartão de crédito', 'cancelamento do cartão de crédito', 'renegociação - palavra curta', 'rotativo - pagamento mínimo']
# Scores [1.8387058973312378, 1.611733317375183, 1.511478304862976, 1.367668628692627, 1.2393641471862793, 1.2189874649047852, 1.201995849609375]
# True Label: rotativo - pagamento mínimo
#
# Ranking Preds ['rotativo - pagamento mínimo', 'avaliação emergencial de crédito', 'desbloquear o cartão', 'renegociação - palavra curta', 'contestar transações', 'alterar limite do cartão de crédito', 'cancelamento do cartão de crédito']
# Scores [1.8092881441116333, 1.6687922477722168, 1.5645759105682373, 1.4768527746200562, 1.4099739789962769, 1.3067480325698853, 1.1804267168045044]
# True Label: rotativo - pagamento mínimo
#
# Ranking Preds ['contestar transações', 'cancelamento do cartão de crédito', 'desbloquear o cartão', 'alterar limite do cartão de crédito', 'renegociação - palavra curta', 'avaliação emergencial de crédito', 'rotativo - pagamento mínimo']
# Scores [1.8265798091888428, 1.737009882926941, 1.6350059509277344, 1.4582210779190063, 1.2804032564163208, 1.1863913536071777, 1.1599442958831787]
# True Label: contestar transações
#
# Ranking Preds ['cancelamento do cartão de crédito', 'rotativo - pagamento mínimo', 'alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'renegociação - palavra curta', 'contestar transações', 'desbloquear o cartão']
# Scores [1.7569403648376465, 1.7134859561920166, 1.638857126235962, 1.5804160833358765, 1.5415494441986084, 1.3465410470962524, 1.2991905212402344]
# True Label: avaliação emergencial de crédito
#
# Ranking Preds ['alterar limite do cartão de crédito', 'desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta', 'avaliação emergencial de crédito']
# Scores [1.845292329788208, 1.6642931699752808, 1.6204911470413208, 1.6053955554962158, 1.4260585308074951, 1.270004153251648, 1.217119812965393]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['desbloquear o cartão', 'alterar limite do cartão de crédito', 'contestar transações', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta', 'avaliação emergencial de crédito']
# Scores [1.7979259490966797, 1.7558037042617798, 1.6620111465454102, 1.5311585664749146, 1.3934223651885986, 1.3401261568069458, 1.2569762468338013]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['desbloquear o cartão', 'alterar limite do cartão de crédito', 'contestar transações', 'renegociação - palavra curta', 'avaliação emergencial de crédito', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo']
# Scores [1.8722447156906128, 1.406313180923462, 1.3582935333251953, 1.2618013620376587, 1.2258317470550537, 1.1985143423080444, 1.0863415002822876]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['desbloquear o cartão', 'alterar limite do cartão de crédito', 'renegociação - palavra curta', 'avaliação emergencial de crédito', 'contestar transações', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo']
# Scores [1.8458648920059204, 1.4509838819503784, 1.4109604358673096, 1.2180755138397217, 1.1840335130691528, 1.1628957986831665, 1.1607229709625244]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['renegociação - palavra curta', 'rotativo - pagamento mínimo', 'cancelamento do cartão de crédito', 'desbloquear o cartão', 'contestar transações', 'avaliação emergencial de crédito', 'alterar limite do cartão de crédito']
# Scores [1.8855339288711548, 1.6041394472122192, 1.4457087516784668, 1.33104407787323, 1.2908968925476074, 1.1560695171356201, 1.0735645294189453]
# True Label: rotativo - pagamento mínimo
#
# Ranking Preds ['desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'alterar limite do cartão de crédito', 'renegociação - palavra curta', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito']
# Scores [1.8043330907821655, 1.7730255126953125, 1.5702141523361206, 1.439806580543518, 1.3568463325500488, 1.3065447807312012, 1.2179633378982544]
# True Label: renegociação - palavra curta
#
# Ranking Preds ['alterar limite do cartão de crédito', 'cancelamento do cartão de crédito', 'contestar transações', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito', 'renegociação - palavra curta']
# Scores [1.8839884996414185, 1.651535987854004, 1.5447344779968262, 1.5399420261383057, 1.320368766784668, 1.2659989595413208, 1.2651532888412476]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['cancelamento do cartão de crédito', 'alterar limite do cartão de crédito', 'desbloquear o cartão', 'contestar transações', 'renegociação - palavra curta', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito']
# Scores [1.804121494293213, 1.7622076272964478, 1.614310383796692, 1.5997825860977173, 1.4147950410842896, 1.38520085811615, 1.2550644874572754]
# True Label: cancelamento do cartão de crédito
#
# Ranking Preds ['contestar transações', 'avaliação emergencial de crédito', 'desbloquear o cartão', 'alterar limite do cartão de crédito', 'renegociação - palavra curta', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo']
# Scores [1.7541372776031494, 1.7411324977874756, 1.5265740156173706, 1.5168567895889282, 1.3069803714752197, 1.1466246843338013, 1.1441329717636108]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['rotativo - pagamento mínimo', 'contestar transações', 'cancelamento do cartão de crédito', 'avaliação emergencial de crédito', 'renegociação - palavra curta', 'desbloquear o cartão', 'alterar limite do cartão de crédito']
# Scores [1.7540042400360107, 1.7026312351226807, 1.5183688402175903, 1.481398344039917, 1.4071147441864014, 1.3050708770751953, 1.007967233657837]
# True Label: cancelamento do cartão de crédito
#
# Ranking Preds ['avaliação emergencial de crédito', 'contestar transações', 'alterar limite do cartão de crédito', 'cancelamento do cartão de crédito', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'renegociação - palavra curta']
# Scores [1.7608076333999634, 1.7506338357925415, 1.553341269493103, 1.4876552820205688, 1.4393956661224365, 1.2643754482269287, 1.133417010307312]
# True Label: desbloquear o cartão
#
# Ranking Preds ['desbloquear o cartão', 'cancelamento do cartão de crédito', 'alterar limite do cartão de crédito', 'contestar transações', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito', 'renegociação - palavra curta']
# Scores [1.8531569242477417, 1.6983747482299805, 1.5981085300445557, 1.4667680263519287, 1.4438368082046509, 1.4316414594650269, 1.29521644115448]
# True Label: cancelamento do cartão de crédito
#
# Ranking Preds ['avaliação emergencial de crédito', 'desbloquear o cartão', 'contestar transações', 'alterar limite do cartão de crédito', 'renegociação - palavra curta', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo']
# Scores [1.81131911277771, 1.653599500656128, 1.5337070226669312, 1.4412864446640015, 1.1999329328536987, 1.150646686553955, 1.1458697319030762]
# True Label: avaliação emergencial de crédito
#
# Ranking Preds ['alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'renegociação - palavra curta', 'rotativo - pagamento mínimo']
# Scores [1.8387514352798462, 1.6964170932769775, 1.3847278356552124, 1.2838362455368042, 1.2346643209457397, 1.122306227684021, 1.0758517980575562]
# True Label: avaliação emergencial de crédito
#
# Ranking Preds ['avaliação emergencial de crédito', 'alterar limite do cartão de crédito', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'contestar transações', 'renegociação - palavra curta', 'cancelamento do cartão de crédito']
# Scores [1.913871169090271, 1.5864789485931396, 1.4451379776000977, 1.38740873336792, 1.3157720565795898, 1.1571218967437744, 1.093207597732544]
# True Label: avaliação emergencial de crédito
#
# Ranking Preds ['cancelamento do cartão de crédito', 'alterar limite do cartão de crédito', 'contestar transações', 'desbloquear o cartão', 'renegociação - palavra curta', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito']
# Scores [1.8162592649459839, 1.7285324335098267, 1.6477583646774292, 1.4713901281356812, 1.4168184995651245, 1.3428109884262085, 1.1597470045089722]
# True Label: renegociação - palavra curta
#
# Ranking Preds ['desbloquear o cartão', 'cancelamento do cartão de crédito', 'alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'contestar transações', 'renegociação - palavra curta', 'rotativo - pagamento mínimo']
# Scores [1.886472225189209, 1.5590732097625732, 1.5333130359649658, 1.4258474111557007, 1.3444699048995972, 1.1770851612091064, 1.1155556440353394]
# True Label: desbloquear o cartão
#
# Ranking Preds ['rotativo - pagamento mínimo', 'renegociação - palavra curta', 'avaliação emergencial de crédito', 'desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'alterar limite do cartão de crédito']
# Scores [1.8919296264648438, 1.5477218627929688, 1.5457303524017334, 1.489915370941162, 1.477262020111084, 1.4687483310699463, 1.3288370370864868]
# True Label: desbloquear o cartão
#
# Ranking Preds ['contestar transações', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'cancelamento do cartão de crédito', 'renegociação - palavra curta', 'alterar limite do cartão de crédito', 'avaliação emergencial de crédito']
# Scores [1.7687833309173584, 1.7572379112243652, 1.5139620304107666, 1.4979512691497803, 1.4373327493667603, 1.4150551557540894, 1.163963794708252]
# True Label: desbloquear o cartão
#
# Ranking Preds ['alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'renegociação - palavra curta', 'rotativo - pagamento mínimo']
# Scores [1.9036078453063965, 1.545003056526184, 1.487399935722351, 1.3297181129455566, 1.2205886840820312, 1.1324869394302368, 1.1129075288772583]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['avaliação emergencial de crédito', 'desbloquear o cartão', 'contestar transações', 'alterar limite do cartão de crédito', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta']
# Scores [1.7539153099060059, 1.6834306716918945, 1.654255986213684, 1.552022099494934, 1.3192745447158813, 1.2289924621582031, 1.129457712173462]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['alterar limite do cartão de crédito', 'contestar transações', 'cancelamento do cartão de crédito', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito', 'renegociação - palavra curta']
# Scores [1.802320957183838, 1.754579782485962, 1.5462768077850342, 1.4971857070922852, 1.426863431930542, 1.4062658548355103, 1.2720153331756592]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['contestar transações', 'cancelamento do cartão de crédito', 'alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'renegociação - palavra curta']
# Scores [1.695002794265747, 1.6711349487304688, 1.6197559833526611, 1.4943386316299438, 1.2307658195495605, 1.21620512008667, 1.0585557222366333]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['desbloquear o cartão', 'cancelamento do cartão de crédito', 'contestar transações', 'alterar limite do cartão de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta', 'avaliação emergencial de crédito']
# Scores [1.7730627059936523, 1.7531135082244873, 1.7280783653259277, 1.4657917022705078, 1.306725025177002, 1.2195621728897095, 1.177574634552002]
# True Label: contestar transações
#
# Ranking Preds ['desbloquear o cartão', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo', 'alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'renegociação - palavra curta', 'contestar transações']
# Scores [1.784271001815796, 1.7800534963607788, 1.6046515703201294, 1.52871572971344, 1.4414331912994385, 1.385921835899353, 1.323804497718811]
# True Label: contestar transações
#
# Ranking Preds ['contestar transações', 'desbloquear o cartão', 'cancelamento do cartão de crédito', 'alterar limite do cartão de crédito', 'renegociação - palavra curta', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito']
# Scores [1.8328564167022705, 1.677296757698059, 1.6465191841125488, 1.3267580270767212, 1.2903366088867188, 1.111331582069397, 1.0689011812210083]
# True Label: contestar transações
#
# Ranking Preds ['avaliação emergencial de crédito', 'alterar limite do cartão de crédito', 'desbloquear o cartão', 'contestar transações', 'rotativo - pagamento mínimo', 'cancelamento do cartão de crédito', 'renegociação - palavra curta']
# Scores [1.8846001625061035, 1.5646686553955078, 1.4941405057907104, 1.2958582639694214, 1.206239104270935, 1.191475749015808, 1.0822608470916748]
# True Label: avaliação emergencial de crédito
#
# Ranking Preds ['alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'desbloquear o cartão', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta', 'contestar transações']
# Scores [1.8706855773925781, 1.5957937240600586, 1.4424200057983398, 1.3148283958435059, 1.2054240703582764, 1.140863060951233, 1.126508116722107]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['desbloquear o cartão', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo', 'alterar limite do cartão de crédito', 'contestar transações', 'renegociação - palavra curta', 'avaliação emergencial de crédito']
# Scores [1.834789514541626, 1.6863408088684082, 1.5733445882797241, 1.571889042854309, 1.5266284942626953, 1.460121750831604, 1.3529540300369263]
# True Label: cancelamento do cartão de crédito
#
# Ranking Preds ['cancelamento do cartão de crédito', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'alterar limite do cartão de crédito', 'contestar transações', 'renegociação - palavra curta', 'avaliação emergencial de crédito']
# Scores [1.8307905197143555, 1.77712082862854, 1.5813521146774292, 1.5411485433578491, 1.455602765083313, 1.2810323238372803, 1.2552905082702637]
# True Label: rotativo - pagamento mínimo
#
# Ranking Preds ['cancelamento do cartão de crédito', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'alterar limite do cartão de crédito', 'contestar transações', 'avaliação emergencial de crédito', 'renegociação - palavra curta']
# Scores [1.811718225479126, 1.7799235582351685, 1.5913326740264893, 1.5675846338272095, 1.3926267623901367, 1.309216022491455, 1.2607115507125854]
# True Label: rotativo - pagamento mínimo
#
# Ranking Preds ['contestar transações', 'desbloquear o cartão', 'cancelamento do cartão de crédito', 'renegociação - palavra curta', 'alterar limite do cartão de crédito', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito']
# Scores [1.8805668354034424, 1.5851802825927734, 1.4242311716079712, 1.367099642753601, 1.352795124053955, 1.1343929767608643, 1.0617294311523438]
# True Label: contestar transações
#
# Ranking Preds ['avaliação emergencial de crédito', 'alterar limite do cartão de crédito', 'desbloquear o cartão', 'rotativo - pagamento mínimo', 'contestar transações', 'renegociação - palavra curta', 'cancelamento do cartão de crédito']
# Scores [1.9104546308517456, 1.6075671911239624, 1.3610860109329224, 1.2957950830459595, 1.2309578657150269, 1.2014625072479248, 1.0552259683609009]
# True Label: avaliação emergencial de crédito
#
# Ranking Preds ['rotativo - pagamento mínimo', 'renegociação - palavra curta', 'avaliação emergencial de crédito', 'contestar transações', 'alterar limite do cartão de crédito', 'desbloquear o cartão', 'cancelamento do cartão de crédito']
# Scores [1.7463352680206299, 1.7394025325775146, 1.6239290237426758, 1.4067333936691284, 1.4047983884811401, 1.31388258934021, 1.0962598323822021]
# True Label: contestar transações
#
# Ranking Preds ['desbloquear o cartão', 'cancelamento do cartão de crédito', 'contestar transações', 'alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta']
# Scores [1.8655436038970947, 1.7158246040344238, 1.5096558332443237, 1.4993401765823364, 1.4175527095794678, 1.3833297491073608, 1.3411246538162231]
# True Label: contestar transações
#
# Ranking Preds ['alterar limite do cartão de crédito', 'desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'avaliação emergencial de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta']
# Scores [1.804444670677185, 1.783217430114746, 1.5983134508132935, 1.5846569538116455, 1.4021540880203247, 1.3188422918319702, 1.2871434688568115]
# True Label: contestar transações
#
# Ranking Preds ['contestar transações', 'desbloquear o cartão', 'cancelamento do cartão de crédito', 'alterar limite do cartão de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta', 'avaliação emergencial de crédito']
# Scores [1.8558590412139893, 1.6921067237854004, 1.6179004907608032, 1.3751943111419678, 1.3269007205963135, 1.3196159601211548, 1.1784766912460327]
# True Label: contestar transações
#
# Ranking Preds ['alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'desbloquear o cartão', 'contestar transações', 'rotativo - pagamento mínimo', 'renegociação - palavra curta', 'cancelamento do cartão de crédito']
# Scores [1.8934154510498047, 1.5785434246063232, 1.4463081359863281, 1.3727418184280396, 1.1541134119033813, 1.1281936168670654, 1.1146323680877686]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'renegociação - palavra curta', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito', 'alterar limite do cartão de crédito']
# Scores [1.7299350500106812, 1.708627700805664, 1.418475866317749, 1.3786686658859253, 1.1658750772476196, 1.1375764608383179, 1.0302157402038574]
# True Label: contestar transações
#
# Ranking Preds ['avaliação emergencial de crédito', 'alterar limite do cartão de crédito', 'contestar transações', 'desbloquear o cartão', 'renegociação - palavra curta', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo']
# Scores [1.8836091756820679, 1.6455869674682617, 1.5082926750183105, 1.4865342378616333, 1.3135908842086792, 1.220056176185608, 1.168632984161377]
# True Label: cancelamento do cartão de crédito
#
# Ranking Preds ['contestar transações', 'alterar limite do cartão de crédito', 'desbloquear o cartão', 'renegociação - palavra curta', 'rotativo - pagamento mínimo', 'cancelamento do cartão de crédito', 'avaliação emergencial de crédito']
# Scores [1.7786989212036133, 1.712480902671814, 1.5543018579483032, 1.4629182815551758, 1.3140604496002197, 1.2816710472106934, 1.1837466955184937]
# True Label: alterar limite do cartão de crédito
#
# Ranking Preds ['desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'renegociação - palavra curta', 'alterar limite do cartão de crédito', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito']
# Scores [1.7933650016784668, 1.6441833972930908, 1.4249401092529297, 1.2306276559829712, 1.1698315143585205, 1.1370267868041992, 0.9695494174957275]
# True Label: desbloquear o cartão
#
# Ranking Preds ['desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'renegociação - palavra curta', 'alterar limite do cartão de crédito', 'rotativo - pagamento mínimo', 'avaliação emergencial de crédito']
# Scores [1.7825438976287842, 1.6597867012023926, 1.4014549255371094, 1.232291340827942, 1.19035804271698, 1.1232432126998901, 0.957395076751709]
# True Label: desbloquear o cartão
#
# Ranking Preds ['desbloquear o cartão', 'contestar transações', 'cancelamento do cartão de crédito', 'rotativo - pagamento mínimo', 'renegociação - palavra curta', 'avaliação emergencial de crédito', 'alterar limite do cartão de crédito']
# Scores [1.8433492183685303, 1.5278587341308594, 1.5111877918243408, 1.2619661092758179, 1.1658427715301514, 1.15343177318573, 1.0968570709228516]
# True Label: desbloquear o cartão
#
# Ranking Preds ['rotativo - pagamento mínimo', 'desbloquear o cartão', 'renegociação - palavra curta', 'contestar transações', 'alterar limite do cartão de crédito', 'avaliação emergencial de crédito', 'cancelamento do cartão de crédito']
# Scores [1.75551176071167, 1.5857363939285278, 1.4668196439743042, 1.4232243299484253, 1.1775784492492676, 1.113128900527954, 1.0636307001113892]
# True Label: rotativo - pagamento mínimo
#
# Ranking Preds ['renegociação - palavra curta', 'alterar limite do cartão de crédito', 'rotativo - pagamento mínimo', 'desbloquear o cartão', 'avaliação emergencial de crédito', 'cancelamento do cartão de crédito', 'contestar transações']
# Scores [1.8522180318832397, 1.6097865104675293, 1.5901601314544678, 1.5756880044937134, 1.3649755716323853, 1.2892309427261353, 1.082285761833191]
# True Label: alterar limite do cartão de crédito
#
#
#
#
#
# Ranking metrics at 1000 examples
# - - - - - - - - - -
# MRR@1  = 0.502
# MRR@2  = 0.6
# MRR@3  = 0.638
# - - - - - - - - - -
# Recall@1  = 0.502
# Recall@2  = 0.698
# Recall@3  = 0.81
# - - - - - - - - - -
# Success@1  = 0.502
# Success@2  = 0.698
# Success@3  = 0.81
# - - - - - - - - - -
#
# Ranking metrics at 2000 examples
# - - - - - - - - - -
# MRR@1  = 0.5
# MRR@2  = 0.595
# MRR@3  = 0.631
# - - - - - - - - - -
# Recall@1  = 0.5
# Recall@2  = 0.689
# Recall@3  = 0.799
# - - - - - - - - - -
# Success@1  = 0.5
# Success@2  = 0.689
# Success@3  = 0.799
# - - - - - - - - - -
#
# Ranking metrics at 3000 examples
# - - - - - - - - - -
# MRR@1  = 0.491
# MRR@2  = 0.584
# MRR@3  = 0.622
# - - - - - - - - - -
# Recall@1  = 0.491
# Recall@2  = 0.676
# Recall@3  = 0.79
# - - - - - - - - - -
# Success@1  = 0.491
# Success@2  = 0.676
# Success@3  = 0.79
# - - - - - - - - - -
#
# Ranking metrics at 4000 examples
# - - - - - - - - - -
# MRR@1  = 0.48
# MRR@2  = 0.573
# MRR@3  = 0.612
# - - - - - - - - - -
# Recall@1  = 0.48
# Recall@2  = 0.665
# Recall@3  = 0.783
# - - - - - - - - - -
# Success@1  = 0.48
# Success@2  = 0.665
# Success@3  = 0.783
# - - - - - - - - - -
#
# Ranking metrics at 5000 examples
# - - - - - - - - - -
# MRR@1  = 0.482
# MRR@2  = 0.575
# MRR@3  = 0.613
# - - - - - - - - - -
# Recall@1  = 0.482
# Recall@2  = 0.668
# Recall@3  = 0.782
# - - - - - - - - - -
# Success@1  = 0.482
# Success@2  = 0.668
# Success@3  = 0.782
# - - - - - - - - - -
#
# Ranking metrics at 6000 examples
# - - - - - - - - - -
# MRR@1  = 0.483
# MRR@2  = 0.575
# MRR@3  = 0.614
# - - - - - - - - - -
# Recall@1  = 0.483
# Recall@2  = 0.668
# Recall@3  = 0.784
# - - - - - - - - - -
# Success@1  = 0.483
# Success@2  = 0.668
# Success@3  = 0.784
# - - - - - - - - - -
#
# Ranking metrics at 7000 examples
# - - - - - - - - - -
# MRR@1  = 0.479
# MRR@2  = 0.571
# MRR@3  = 0.61
# - - - - - - - - - -
# Recall@1  = 0.479
# Recall@2  = 0.664
# Recall@3  = 0.78
# - - - - - - - - - -
# Success@1  = 0.479
# Success@2  = 0.664
# Success@3  = 0.78
# - - - - - - - - - -
#
# Ranking metrics at 8000 examples
# - - - - - - - - - -
# MRR@1  = 0.481
# MRR@2  = 0.573
# MRR@3  = 0.612
# - - - - - - - - - -
# Recall@1  = 0.481
# Recall@2  = 0.665
# Recall@3  = 0.783
# - - - - - - - - - -
# Success@1  = 0.481
# Success@2  = 0.665
# Success@3  = 0.783
# - - - - - - - - - -
#
# Ranking metrics at 9000 examples
# - - - - - - - - - -
# MRR@1  = 0.483
# MRR@2  = 0.575
# MRR@3  = 0.614
# - - - - - - - - - -
# Recall@1  = 0.483
# Recall@2  = 0.666
# Recall@3  = 0.783
# - - - - - - - - - -
# Success@1  = 0.483
# Success@2  = 0.666
# Success@3  = 0.783
# - - - - - - - - - -
#
# Ranking metrics at 10000 examples
# - - - - - - - - - -
# MRR@1  = 0.484
# MRR@2  = 0.575
# MRR@3  = 0.614
# - - - - - - - - - -
# Recall@1  = 0.484
# Recall@2  = 0.666
# Recall@3  = 0.783
# - - - - - - - - - -
# Success@1  = 0.484
# Success@2  = 0.666
# Success@3  = 0.783
# - - - - - - - - - -
#
# Ranking metrics at 11000 examples
# - - - - - - - - - -
# MRR@1  = 0.482
# MRR@2  = 0.573
# MRR@3  = 0.612
# - - - - - - - - - -
# Recall@1  = 0.482
# Recall@2  = 0.664
# Recall@3  = 0.781
# - - - - - - - - - -
# Success@1  = 0.482
# Success@2  = 0.664
# Success@3  = 0.781
# - - - - - - - - - -
#
# Ranking metrics at 12000 examples
# - - - - - - - - - -
# MRR@1  = 0.481
# MRR@2  = 0.572
# MRR@3  = 0.611
# - - - - - - - - - -
# Recall@1  = 0.481
# Recall@2  = 0.663
# Recall@3  = 0.78
# - - - - - - - - - -
# Success@1  = 0.481
# Success@2  = 0.663
# Success@3  = 0.78
# - - - - - - - - - -
#
# Ranking metrics at 13000 examples
# - - - - - - - - - -
# MRR@1  = 0.482
# MRR@2  = 0.573
# MRR@3  = 0.612
# - - - - - - - - - -
# Recall@1  = 0.482
# Recall@2  = 0.663
# Recall@3  = 0.781
# - - - - - - - - - -
# Success@1  = 0.482
# Success@2  = 0.663
# Success@3  = 0.781
# - - - - - - - - - -
#
# Ranking metrics at 14000 examples
# - - - - - - - - - -
# MRR@1  = 0.484
# MRR@2  = 0.574
# MRR@3  = 0.614
# - - - - - - - - - -
# Recall@1  = 0.484
# Recall@2  = 0.664
# Recall@3  = 0.783
# - - - - - - - - - -
# Success@1  = 0.484
# Success@2  = 0.664
# Success@3  = 0.783
# - - - - - - - - - -
#
# Ranking metrics at 15000 examples
# - - - - - - - - - -
# MRR@1  = 0.485
# MRR@2  = 0.574
# MRR@3  = 0.614
# - - - - - - - - - -
# Recall@1  = 0.485
# Recall@2  = 0.664
# Recall@3  = 0.784
# - - - - - - - - - -
# Success@1  = 0.485
# Success@2  = 0.664
# Success@3  = 0.784
# - - - - - - - - - -
#
# Ranking metrics at 16000 examples
# - - - - - - - - - -
# MRR@1  = 0.483
# MRR@2  = 0.573
# MRR@3  = 0.613
# - - - - - - - - - -
# Recall@1  = 0.483
# Recall@2  = 0.662
# Recall@3  = 0.783
# - - - - - - - - - -
# Success@1  = 0.483
# Success@2  = 0.662
# Success@3  = 0.783
# - - - - - - - - - -
#
# Ranking metrics at 17000 examples
# - - - - - - - - - -
# MRR@1  = 0.481
# MRR@2  = 0.571
# MRR@3  = 0.611
# - - - - - - - - - -
# Recall@1  = 0.481
# Recall@2  = 0.66
# Recall@3  = 0.782
# - - - - - - - - - -
# Success@1  = 0.481
# Success@2  = 0.66
# Success@3  = 0.782
# - - - - - - - - - -
#
# Ranking metrics at 18000 examples
# - - - - - - - - - -
# MRR@1  = 0.482
# MRR@2  = 0.571
# MRR@3  = 0.611
# - - - - - - - - - -
# Recall@1  = 0.482
# Recall@2  = 0.66
# Recall@3  = 0.781
# - - - - - - - - - -
# Success@1  = 0.482
# Success@2  = 0.66
# Success@3  = 0.781
# - - - - - - - - - -
#
# Ranking metrics at 19000 examples
# - - - - - - - - - -
# MRR@1  = 0.482
# MRR@2  = 0.571
# MRR@3  = 0.612
# - - - - - - - - - -
# Recall@1  = 0.482
# Recall@2  = 0.66
# Recall@3  = 0.782
# - - - - - - - - - -
# Success@1  = 0.482
# Success@2  = 0.66
# Success@3  = 0.782
# - - - - - - - - - -
# F1: 0.404 -- time:

# %% [markdown]
# ## Eval Metrics

# %%
# predictions 
preds_dist = pd.DataFrame(preds)[0].apply(lambda x: int_to_class[x]).value_counts().sort_index()
preds_dist
# Out:
# alterar limite do cartão de crédito    5420
# avaliação emergencial de crédito       4649
# cancelamento do cartão de crédito      1531
# contestar transações                   3618
# desbloquear o cartão                   2873
# renegociação - palavra curta            436
# rotativo - pagamento mínimo            1164
# Name: 0, dtype: int64

# %%
# trues 
trues_dist = pd.DataFrame(trues)[0].apply(lambda x: int_to_class[x]).value_counts().sort_index()
trues_dist
# Out:
# alterar limite do cartão de crédito    6347
# avaliação emergencial de crédito       3855
# cancelamento do cartão de crédito      1740
# contestar transações                   2781
# desbloquear o cartão                   2792
# renegociação - palavra curta           1114
# rotativo - pagamento mínimo            1062
# Name: 0, dtype: int64

# %% [markdown]
# ## DML (Deep Metric Learning) - Ranking - Result test dataset

# %%
print(classification_report(trues, preds, target_names=list(data_feats['assuntos'].keys())))
# Out:
#                                      precision    recall  f1-score   support
#
#   cancelamento do cartão de crédito       0.37      0.32      0.35      1740
#    avaliação emergencial de crédito       0.61      0.73      0.66      3855
#                contestar transações       0.35      0.45      0.40      2781
#                desbloquear o cartão       0.35      0.36      0.35      2792
#         rotativo - pagamento mínimo       0.30      0.33      0.32      1062
# alterar limite do cartão de crédito       0.61      0.52      0.57      6347
#        renegociação - palavra curta       0.34      0.13      0.19      1114
#
#                            accuracy                           0.48     19691
#                           macro avg       0.42      0.41      0.40     19691
#                        weighted avg       0.48      0.48      0.48     19691

# %% [markdown]
# # Classificação
#                                          precision   recall   f1-score  support
#     cancelamento do cartão de crédito       0.36      0.33      0.34      1764
#     avaliação emergencial de crédito        0.61      0.73      0.66      3976
#     contestar transações                    0.31      0.54      0.39      2815
#     desbloquear o cartão                    0.35      0.35      0.35      2836
#     rotativo - pagamento mínimo             0.33      0.29      0.31      1081
#     alterar limite do cartão de crédito     0.66      0.47      0.55      6463
#     renegociação - palavra curta            0.39      0.12      0.18      1115
#
#     accuracy                                                    0.47     20050
#     macro avg                               0.43      0.40      0.40     20050
#     weighted avg                            0.50      0.47      0.47     20050
