# %% [markdown]
# <a href="https://colab.research.google.com/github/finardi/tutos/blob/master/pretrain_wav2vec2_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q accelerate datasets torchaudio
# Out:
#      |████████████████████████████████| 58 kB 4.1 MB/s
#      |████████████████████████████████| 306 kB 13.9 MB/s
#      |████████████████████████████████| 243 kB 93.5 MB/s
#      |████████████████████████████████| 1.1 MB 91.4 MB/s
#      |████████████████████████████████| 133 kB 104.7 MB/s
#      |████████████████████████████████| 67 kB 7.6 MB/s
#      |████████████████████████████████| 271 kB 86.6 MB/s
#      |████████████████████████████████| 160 kB 91.5 MB/s
#      |████████████████████████████████| 144 kB 87.0 MB/s

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 3.4 MB 7.8 MB/s
#      |████████████████████████████████| 3.3 MB 76.6 MB/s
#      |████████████████████████████████| 596 kB 89.5 MB/s
#      |████████████████████████████████| 895 kB 79.3 MB/s

# %%
# !git clone https://github.com/huggingface/transformers
# !cd transformers && pip install -e .
# !cd transformers
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 97016, done.
# remote: Total 97016 (delta 0), reused 0 (delta 0), pack-reused 97016
# Receiving objects: 100% (97016/97016), 82.03 MiB | 36.10 MiB/s, done.
# Resolving deltas: 100% (70410/70410), done.

# %%
# !cp transformers/examples/pytorch/speech-pretraining/run_wav2vec2_pretraining_no_trainer.py .

# %%
# !accelerate launch run_wav2vec2_pretraining_no_trainer.py \
	--dataset_name="librispeech_asr" \
	--dataset_config_names clean clean \
	--dataset_split_names validation test \
	--model_name_or_path="patrickvonplaten/wav2vec2-base-v2" \
	--output_dir="./wav2vec2-pretrained-demo" \
	--max_train_steps="20000" \
	--num_warmup_steps="32000" \
	--gradient_accumulation_steps="8" \
	--learning_rate="0.005" \
	--weight_decay="0.01" \
	--max_duration_in_seconds="20.0" \
	--min_duration_in_seconds="2.0" \
	--logging_steps="1" \
	--saving_steps="10000" \
	--per_device_train_batch_size="4" \
	--per_device_eval_batch_size="4" \
	--adam_beta1="0.9" \
	--adam_beta2="0.98" \
	--adam_epsilon="1e-06" \
	--gradient_checkpointing \
# Out:
# Downloading: 6.76kB [00:00, 8.46MB/s]
# Downloading: 6.39kB [00:00, 9.38MB/s]
# ...
#   0% 0/4 [00:00<?, ?it/s]
# Downloading:   0% 0.00/338M [00:00<?, ?B/s]
# Downloading:   0% 8.19k/338M [00:00<1:33:42, 60.1kB/s]
# Downloading:   0% 39.9k/338M [00:00<35:19, 159kB/s]
# Downloading:   0% 96.3k/338M [00:00<20:45, 271kB/s]
# Downloading:   0% 209k/338M [00:00<11:38, 483kB/s]
# Downloading:   0% 440k/338M [00:00<06:11, 908kB/s]
# Downloading:   0% 904k/338M [00:00<03:14, 1.73MB/s]
# Downloading:   1% 1.82M/338M [00:00<01:41, 3.32MB/s]
# Downloading:   1% 3.67M/338M [00:01<00:51, 6.48MB/s]
# Downloading:   2% 5.85M/338M [00:01<00:35, 9.33MB/s]
# Downloading:   2% 7.86M/338M [00:01<00:30, 10.9MB/s]
# Downloading:   3% 9.90M/338M [00:01<00:27, 12.0MB/s]
# Downloading:   4% 12.0M/338M [00:01<00:25, 12.9MB/s]
# Downloading:   4% 14.0M/338M [00:01<00:24, 13.4MB/s]
# Downloading:   5% 16.0M/338M [00:01<00:23, 13.8MB/s]
# Downloading:   5% 18.1M/338M [00:02<00:22, 14.0MB/s]
# ...
